# %%
import numpy as np 
import pandas as pd 
import matplotlib
# %matplotlib inline

# %%
df = pd.read_csv("weatherHistory_v1.csv")
data_series = df["Temperature (C)"]
data_series.describe()
# Out:
# count    59538.000000
# mean        11.832714
# std          9.805586
# min        -21.822222
# 25%          4.061111
# 50%         12.038889
# 75%         18.877778
# max         39.588889
# Name: Temperature (C), dtype: float64

# %%
df
# Out:
#        Temperature (C)
# 0             0.577778
# 1             1.161111
# 2             1.666667
# 3             1.711111
# 4             1.183333
# ...                ...
# 69995         7.133333
# 69996         8.800000
# 69997         9.883333
# 69998         9.883333
# 69999         8.838889
#
# [70000 rows x 1 columns]

# %%
data_series.isnull().sum()
# Out:
# np.int64(10462)

# %%
data_filled = data_series.interpolate()

# %%
data_filled.plot()
# Out:
# <Axes: >

# %%
data_filled
# Out:
# 0        0.577778
# 1        1.161111
# 2        1.666667
# 3        1.711111
# 4        1.183333
#            ...
# 69995    7.133333
# 69996    8.800000
# 69997    9.883333
# 69998    9.883333
# 69999    8.838889
# Name: Temperature (C), Length: 70000, dtype: float64

# %%
data_small = data_filled[:200]
data_small.plot()
# Out:
# <Axes: >

# %%
data_small.plot.box()
# Out:
# <Axes: >

# %%
data_smooth = data_filled.rolling(window = 5).mean()
data_smooth[:200].plot()
# Out:
# <Axes: >
